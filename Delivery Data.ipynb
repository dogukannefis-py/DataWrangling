# %%
import requests
import json
import pandas as pd
import numpy as np

# %%
key="*****"

# %%
r = requests.get("https://maps.googleapis.com/maps/api/geocode/json?latlng=41.131533,29.094437&key=*******")

# %%
data = json.loads(r.content)
data
# Out:
# {'plus_code': {'compound_code': '43JV+JQ Anatolian Side, İstanbul, Turkey',
#   'global_code': '8GHF43JV+JQ'},
#  'results': [{'access_points': [{'access_point_type': 'TYPE_SEGMENT',
#      'location': {'latitude': 41.1311373, 'longitude': 29.094412},
#      'location_on_segment': {'latitude': 41.1311613, 'longitude': 29.0944893},
#      'place_id': 'ChIJYQ7ZWiDLyhQRHNfVjPratT8',
#      'segment_position': 0.06377845257520676,
#      'unsuitable_travel_modes': []}],
#    'address_components': [{'long_name': '13',
#      'short_name': '13',
#      'types': ['street_number']},
#     {'long_name': 'Talim Çıkmazı Sokağı',
#      'short_name': 'Talim Çk Sok.',
#      'types': ['route']},
#     {'long_name': 'Gümüşsuyu',
#      'short_name': 'Gümüşsuyu',
#      'types': ['administrative_area_level_4', 'political']},
#     {'long_name': 'Beykoz',
#      'short_name': 'Beykoz',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'İstanbul',
# ...

# %%
data['results'][0]['address_components'][3]['long_name']
# Out:
# 'Beykoz'

# %%
for step in data['results']['adress_components'][2]:
    print(step)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-7b99d4924b8c> in <module>
# ----> 1 for step in data['results']['adress_components'][2]:
#       2     print(step)
#
# TypeError: list indices must be integers or slices, not str

# %%
r = requests.get('https://maps.googleapis.com/maps/api/directions/json?origin={},{}&destination={},{}&departure_time={}&mode=driving&key=AIzaSyCv6YJlBcYY8QZKvOEAEgnvzOjziKTH18A'.format(
        s2,s1,pt[1],pt[0],timestamp))

# %%
lat=41.13087489999999
lng= 29.0932083197085

# %%
r = requests.get("https://maps.googleapis.com/maps/api/geocode/json?latlng={},{}&key=AIzaSyAgbgfdMl-TgNsOXlWcaKSJEOH-emqt6oM".format(
        lat,lng))

# %%
data = json.loads(r.content)
data
# Out:
# {'plus_code': {'compound_code': '43JV+87 Anatolian Side, İstanbul, Turkey',
#   'global_code': '8GHF43JV+87'},
#  'results': [{'access_points': [],
#    'address_components': [{'long_name': '1 a',
#      'short_name': '1 a',
#      'types': ['street_number']},
#     {'long_name': 'Tan Çıkmazı', 'short_name': 'Tan Çk.', 'types': ['route']},
#     {'long_name': 'Gümüşsuyu',
#      'short_name': 'Gümüşsuyu',
#      'types': ['administrative_area_level_4', 'political']},
#     {'long_name': 'Beykoz',
#      'short_name': 'Beykoz',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'İstanbul',
#      'short_name': 'İstanbul',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Turkey',
#      'short_name': 'TR',
#      'types': ['country', 'political']},
#     {'long_name': '34820', 'short_name': '34820', 'types': ['postal_code']}],
#    'formatted_address': 'Gümüşsuyu, Tan Çk. 1 a, 34820 Beykoz/İstanbul, Turkey',
# ...

# %%
df=pd.read_csv('train.csv')

# %%
df.head(20)
# Out:
#            id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0   id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1   id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2   id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3   id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4   id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
# 5   id0801584          2  2016-01-30 22:01:40  2016-01-30 22:09:03
# 6   id1813257          1  2016-06-17 22:34:59  2016-06-17 22:40:40
# 7   id1324603          2  2016-05-21 07:54:58  2016-05-21 08:20:49
# 8   id1301050          1  2016-05-27 23:12:23  2016-05-27 23:16:38
# 9   id0012891          2  2016-03-10 21:45:01  2016-03-10 22:05:26
# 10  id1436371          2  2016-05-10 22:08:41  2016-05-10 22:29:55
# 11  id1299289          2  2016-05-15 11:16:11  2016-05-15 11:34:59
# 12  id1187965          2  2016-02-19 09:52:46  2016-02-19 10:11:20
# ...

# %%
from google.directions import GoogleDirections
from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-ba29dedaefcd> in <module>
# ----> 1 from google.directions import GoogleDirections
#       2 from datetime import datetime
#
# ~\Anaconda3\lib\site-packages\google\directions\__init__.py in <module>
# ----> 1 from gdapi import GoogleDirections
#
# ModuleNotFoundError: No module named 'gdapi'

# %%
gd = GoogleDirections('AIzaSyCv6YJlBcYY8QZKvOEAEgnvzOjziKTH18A')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-6129905272ca> in <module>
# ----> 1 gd = GoogleDirections('AIzaSyCv6YJlBcYY8QZKvOEAEgnvzOjziKTH18A')
#
# NameError: name 'GoogleDirections' is not defined

# %%
# Geocoding an address
geocode_result = gmaps.geocode('1600 Amphitheatre Parkway, Mountain View, CA')
# Out:
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# <ipython-input-11-251670ddcfda> in <module>
#       1 # Geocoding an address
# ----> 2 geocode_result = gmaps.geocode('1600 Amphitheatre Parkway, Mountain View, CA')
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in wrapper(*args, **kwargs)
#     416     def wrapper(*args, **kwargs):
#     417         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 418         result = func(*args, **kwargs)
#     419         try:
#     420             del args[0]._extra_params
#
# ~\Anaconda3\lib\site-packages\googlemaps\geocoding.py in geocode(client, address, components, bounds, region, language)
#      66         params["language"] = language
#      67
# ---> 68     return client._request("/maps/api/geocode/json", params).get("results", [])
#      69
#      70
#
# ...

# %%
geo
